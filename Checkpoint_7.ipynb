# %%
import pandas as pd
import numpy as np
list1 = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],

'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],

'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],

'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
df = pd.DataFrame(list, columns =['name', 'score', 'attempts', 'qualify'])
label = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df[""] =  label
df = df.set_index('')

df
# Out:
#         name  score  attempts qualify
#
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df.loc["k"]= ["Suresh",15.5,1,"yes"]
df
# Out:
#         name  score  attempts qualify
#
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# k     Suresh   15.5         1     yes

# %%
df.dropna()
# Out:
#         name  score  attempts qualify
#
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# k     Suresh   15.5         1     yes

# %%
df.head(3)
# Out:
#         name  score  attempts qualify
#
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes

# %%
df["success"] = np.where(df["score"] > 10,1,0 )

df
# Out:
#         name  score  attempts qualify  success
#
# a  Anastasia   12.5         1     yes        1
# b       Dima    9.0         3      no        0
# c  Katherine   16.5         2     yes        1
# d      James    NaN         3      no        0
# e      Emily    9.0         2      no        0
# f    Michael   20.0         3     yes        1
# g    Matthew   14.5         1     yes        1
# h      Laura    NaN         1      no        0
# i      Kevin    8.0         2      no        0
# j      Jonas   19.0         1     yes        1
# k     Suresh   15.5         1     yes        1

# %%
df.head(3)
# Out:
#         name  score  attempts qualify  success
#
# a  Anastasia   12.5         1     yes        1
# b       Dima    9.0         3      no        0
# c  Katherine   16.5         2     yes        1

# %%
df = df.drop("attempts",axis = 1)

# %%
df.head(3)
# Out:
#         name  score qualify  success
#
# a  Anastasia   12.5     yes        1
# b       Dima    9.0      no        0
# c  Katherine   16.5     yes        1

# %%
df = df.iloc[:,0:2]

# %%
df.head(3)
# Out:
#         name  score
#
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5

# %%
df.to_csv('my_data.csv')
